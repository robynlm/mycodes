# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data_analysis_codes.tools import LinData
from data_analysis_codes.tools import ReadingTools as RRead
from data_analysis_codes.tools import Cstyle
plt.style.use(Cstyle.style1)

# %%
param = RRead.read_parameters('pflrw_A7e3_L1821_t200_N64_LCDM')
Lin = LinData.LinData_Class(param)
f = pd.read_table(param['datapath']+'h5_data.csv', delimiter=',')
fc = pd.read_table(param['datapath']+'constraints.csv', delimiter=',')
# Out:
#  read time file

# %%
L = param['ICPertFLRW_lambda_pert1']
an = Lin.evo.a(f['t'])/Lin.evo.a(1)

plt.figure(figsize=(12, 5))
plt.subplot(131)
plt.plot(an, f['drho_OD'], color='C1', label='OD')
plt.plot(an, f['drho_cent'], color='C2', label='cent')
plt.plot(an, f['drho_UD'], color='C0', label='UD')
plt.plot(an, Lin.drho(f['t'], loc='OD'), linestyle=':', color='firebrick', label='OD'+r'${}^{(1)}$')
plt.plot(an, Lin.drho(f['t'], loc='cent'), linestyle=':', color='gold', label='cent'+r'${}^{(1)}$')
plt.plot(an, Lin.drho(f['t'], loc='UD'), linestyle=':', color='skyblue', label='UD'+r'${}^{(1)}$')
xmin, xmax = plt.gca().axes.get_xlim()
x = np.arange(xmin-10, xmax+10, 10)
plt.fill_between(x, [-10]*len(x), [-1]*len(x), facecolor='brown', edgecolor=None, alpha=0.2, label='Unphysical')
plt.xlim(xmin, xmax)
plt.grid()
plt.ylim(-2.75, 10)
plt.xlim(0, 60)
plt.xlabel(r'$a/a_{IN}$')
plt.title(r'$\delta$')

plt.subplot(132)
plt.plot(an, f['dgdet_OD'], color='C1', label='OD')
plt.plot(an, f['dgdet_cent'], color='C2', label='cent')
plt.plot(an, f['dgdet_UD'], color='C0', label='UD')
plt.plot(an, Lin.dgdet(f['t'], loc='OD'), linestyle=':', color='firebrick', label='OD'+r'${}^{(1)}$')
plt.plot(an, Lin.dgdet(f['t'], loc='cent'), linestyle=':', color='gold', label='cent'+r'${}^{(1)}$')
plt.plot(an, Lin.dgdet(f['t'], loc='UD'), linestyle=':', color='skyblue', label='UD'+r'${}^{(1)}$')
xmin, xmax = plt.gca().axes.get_xlim()
x = np.arange(xmin-10, xmax+10, 10)
plt.fill_between(x, [-10]*len(x), [-1]*len(x), facecolor='brown', edgecolor=None, alpha=0.2, label='Unphysical')
plt.xlim(xmin, xmax)
plt.grid()
plt.ylim(-2.75, 10)
plt.xlim(0, 60)
plt.xlabel(r'$a/a_{IN}$')
plt.title(r'$\delta\gamma$')

plt.subplot(133)
plt.plot(an, f['dK_OD'], color='C1', label='OD')
plt.plot(an, f['dK_cent'], color='C2', label='cent')
plt.plot(an, f['dK_UD'], color='C0', label='UD')
plt.plot(an, Lin.dK(f['t'], loc='OD'), linestyle=':', color='firebrick', label='OD'+r'${}^{(1)}$')
plt.plot(an, Lin.dK(f['t'], loc='cent'), linestyle=':', color='gold', label='cent'+r'${}^{(1)}$')
plt.plot(an, Lin.dK(f['t'], loc='UD'), linestyle=':', color='skyblue', label='UD'+r'${}^{(1)}$')
plt.axhline(y=-1, c='brown')
plt.axhline(y=0.5, c='brown')
plt.grid()
plt.ylim(-1.3, 0.75)
plt.xlim(0, 60)
plt.xlabel(r'$a/a_{IN}$')
plt.title(r'$\delta K$')
plt.subplots_adjust(left=0.05, wspace=0.3, right=0.95)

# %%
L = param['ICPertFLRW_lambda_pert1']
plt.figure(figsize=(12, 5))
plt.subplot(131)
a2 = Lin.evo.a(f['t'])**2
plt.plot(an, a2*f['RicciS_OD']*(L**2), color='C1', label='OD')
plt.plot(an, a2*f['RicciS_cent']*(L**2), color='C2', label='cent')
plt.plot(an, a2*f['RicciS_UD']*(L**2), color='C0', label='UD')
plt.plot(an, Lin.dRicciSconf(f['t'], loc='OD')*(L**2), linestyle=':', color='firebrick', label='OD'+r'${}^{(1)}$')
plt.plot(an, Lin.dRicciSconf(f['t'], loc='cent')*(L**2), linestyle=':', color='gold', label='cent'+r'${}^{(1)}$')
plt.plot(an, Lin.dRicciSconf(f['t'], loc='UD')*(L**2), linestyle=':', color='skyblue', label='UD'+r'${}^{(1)}$')
plt.grid()
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(0, 60)
plt.ylim(-1e-6, 8e-6)
plt.title(r'$a^2 \; {}^{(3)}R \;\; [\lambda_{pert}^{-2}]$')

plt.subplot(132)
plt.plot(an, (f['gdet_OD']**(1/3))*f['RicciS_OD']*(L**2), color='C1', label='OD')
plt.plot(an, (f['gdet_cent']**(1/3))*f['RicciS_cent']*(L**2), color='C2', label='cent')
plt.plot(an, (f['gdet_UD']**(1/3))*f['RicciS_UD']*(L**2), color='C0', label='UD')
plt.plot(an, Lin.dRicciSconf(f['t'], loc='OD')*(L**2), linestyle=':', color='firebrick', label='OD'+r'${}^{(1)}$')
plt.plot(an, Lin.dRicciSconf(f['t'], loc='cent')*(L**2), linestyle=':', color='gold', label='cent'+r'${}^{(1)}$')
plt.plot(an, Lin.dRicciSconf(f['t'], loc='UD')*(L**2), linestyle=':', color='skyblue', label='UD'+r'${}^{(1)}$')
plt.grid()
plt.ylim(-1e-6*(L**2), 3e-6*(L**2))
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(0, 60)
plt.title(r'$\gamma^{\frac{1}{3}} \; {}^{(3)}R \;\; [\lambda_{pert}^{-2}]$')

plt.subplot(233)
plt.plot(an, (((f['gdet_cent']**(1/3))*f['RicciS_cent'])
              / ((f['gdet_cent'][0]**(1/3))*f['RicciS_cent'][0])-1), color='C2', label='cent')
plt.grid()
plt.title(r'$\left(\gamma^{\frac{1}{3}} \; {}^{(3)}R \right) / \left(\gamma^{\frac{1}{3}}_{{}_{IN}} \; {}^{(3)}R_{{}_{IN}} \right) - 1$')

plt.subplot(236)
plt.plot(an, (((f['gdet_OD']**(1/3))*f['RicciS_OD'])
              / ((f['gdet_OD'][0]**(1/3))*f['RicciS_OD'][0])-1), color='C1', label='OD')
plt.plot(an, (((f['gdet_UD']**(1/3))*f['RicciS_UD'])
              / ((f['gdet_UD'][0]**(1/3))*f['RicciS_UD'][0])-1), color='C0', label='UD')
plt.grid()
plt.ylim(-0.1, 0.08)
plt.xlim(0, 60)
plt.xlabel(r'$a/a_{IN}$')

plt.subplots_adjust(hspace=0, left=0.05, wspace=0.3, right=0.95)

# %%
plt.figure(figsize=(7, 10))
labsize = 25
alphafac = 0.1
locs = ['maxabs', 'highQabs', 'medianabs', 'lowQabs', 'minabs']
loclabs = ['max', 'first quartile', 'median', 'third quartile', 'min']
cols = plt.cm.viridis(np.linspace(0,1,len(locs)))

ax = plt.subplot(211)
for i, loc, in enumerate(locs):
    for n in range(3):
        varstr = 'Mom'+str(n+1)+'/MomEScale_'+loc
        var = np.array(fc[varstr])
        if n==0:
            ax.semilogy(an, var, color=cols[i], linestyle='-', label=loclabs[i])
        else:
            ax.semilogy(an, var, color=cols[i], linestyle='-')
ax.grid()
ax.legend(bbox_to_anchor=(1,1))
ax.set_xticklabels([])
ax.set_ylim(5e-10, 1)
ax.set_ylabel(r'$|\mathcal{M}_{i}/[\mathcal{M}]|$', fontsize=labsize)


ax = plt.subplot(212)
for i, loc, in enumerate(locs):
        varstr = 'Ham/HamEScale_'+loc
        var = np.array(fc[varstr])
        ax.semilogy(an, var, color=cols[i], linestyle='-')
ax.grid()
ax.set_ylim(1e-11, 2)
ax.set_xlabel(r'$a/a_{IN}$', fontsize=labsize)
ax.set_ylabel(r'$|\mathcal{H}/[\mathcal{H}]|$', fontsize=labsize)

plt.subplots_adjust(hspace=0)

# %%
flab = ['full sim']
paramA = RRead.read_parameters('pflrw_d3e2_L1821_t1_N64_LCDM')
fA = pd.read_table(paramA['datapath']+'h5_data.csv', delimiter=',')

flab += [r'Just change $\tau_{IN}$']
paramB = RRead.read_parameters('pflrw_d3e2_L1821_t200_N64_LCDM')
fB = pd.read_table(paramB['datapath']+'h5_data.csv', delimiter=',')

flab += [r'Fix IC with $\delta$']
paramC = RRead.read_parameters('pflrw_A7e3_L1821_t200_N64_LCDM')
fC = pd.read_table(paramC['datapath']+'h5_data.csv', delimiter=',')

flab += [r'Fix IC with $\gamma^{\frac{1}{3}} \; {}^{(3)}R \;\; [\lambda_{pert}^{-2}]$']
paramD = RRead.read_parameters('pflrw_A6e3_L1821_t200_N64_LCDM')
fD = pd.read_table(paramD['datapath']+'h5_data.csv', delimiter=',')

flab += [r'Fix IC with $K$']
paramE = RRead.read_parameters('pflrw_A1e2_L1821_t200_N64_LCDM')
fE = pd.read_table(paramE['datapath']+'h5_data.csv', delimiter=',')

flab += [r'Fix IC with $\delta$ and then $K$']
paramF = RRead.read_parameters('pflrw_A7e3_A1e2_L1821_t200_N64_LCDM')
fF = pd.read_table(paramF['datapath']+'h5_data.csv', delimiter=',')

flab += [r'Fix IC with $\gamma^{\frac{1}{3}} \; {}^{(3)}R$ and then $K$']
paramG = RRead.read_parameters('pflrw_A6e3_A1e2_L1821_t200_N64_LCDM')
fG = pd.read_table(paramG['datapath']+'h5_data.csv', delimiter=',')

flab += [r'Fix IC with ${}^{(3)}R$ and then $K$']
paramH = RRead.read_parameters('pflrw_A79e4_A1e2_L1821_t200_N64_LCDM_moredata')
fH = pd.read_table(paramH['datapath']+'h5_data.csv', delimiter=',')

Lin = LinData.LinData_Class(paramA)
L = paramA['Lx']
# Out:
#  read time file

# %%
allfs = [fA, fB, fC, fD, fE, fF, fG, fH]
allfs = [fA, fG, fH]
flab = ['full sim']
#flab += [r'Just change $\tau_{IN}$']
#flab += [r'Fix IC with $\delta$']
#flab += [r'Fix IC with $\gamma^{\frac{1}{3}} \; {}^{(3)}R \;\; [\lambda_{pert}^{-2}]$']
#flab += [r'Fix IC with $K$']
#flab += [r'Fix IC with $\delta$ and then $K$']
flab += [r'Fix IC with $\gamma^{\frac{1}{3}} \; {}^{(3)}R$ and then $K$']
flab += [r'Fix IC with ${}^{(3)}R$ and then $K$']

plt.figure(figsize=(25, 7))
plt.subplot(151)
for f in allfs:
    plt.plot(Lin.evo.a(f['t'])/Lin.evo.a(1), f['drho_OD'])
plt.grid()
plt.title(r'$\delta_{OD}$')
plt.xlabel(r'$a/a_{IN}$')
plt.ylim(-1, 30)
plt.xlim(30, 60)

plt.subplot(152)
for f in allfs:
    plt.semilogy(Lin.evo.a(f['t'])/Lin.evo.a(1), abs(f['K_OD']))
    plt.scatter(Lin.evo.a(f['t'])/Lin.evo.a(1), abs(f['K_OD']))
plt.grid()
plt.title(r'$|K_{OD}|$')
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(30, 60)

plt.subplot(153)
for f in allfs:
    plt.semilogy(Lin.evo.a(f['t'])/Lin.evo.a(1), f['gdet_OD'])
plt.grid()
plt.title(r'$\gamma_{OD}$')
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(30, 60)
plt.ylim(1e-9, 3e-6)

plt.subplot(154)
for f in allfs:
    plt.semilogy(Lin.evo.a(f['t'])/Lin.evo.a(1), abs((Lin.evo.a(f['t'])**2)*f['RicciS_OD']*(L**2)))
plt.grid()
plt.title(r'$|a^{2} \; {}^{(3)}R_{OD}| \;\; [\lambda_{pert}^{-2}]$')
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(30, 60)
plt.ylim(1, 2000)

plt.subplot(155)
for f, lab in zip(allfs, flab):
    plt.semilogy(Lin.evo.a(f['t'])/Lin.evo.a(1), abs((f['gdet_OD']**(1/3))*f['RicciS_OD']*(L**2)), label=lab)
plt.grid()
plt.title(r'$|\gamma_{OD}^{\frac{1}{3}} \; {}^{(3)}R_{OD}| \;\; [\lambda_{pert}^{-2}]$')
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(30, 60)
plt.ylim(3e-1, 6e2)
plt.legend(bbox_to_anchor=(1,1))

plt.subplots_adjust(wspace=0.25)

# %%
allfs = [fA, fH]
flab = ['full sim']
#flab += [r'Just change $\tau_{IN}$']
#flab += [r'Fix IC with $\delta$']
#flab += [r'Fix IC with $\gamma^{\frac{1}{3}} \; {}^{(3)}R \;\; [\lambda_{pert}^{-2}]$']
#flab += [r'Fix IC with $K$']
#flab += [r'Fix IC with $\delta$ and then $K$']
#flab += [r'Fix IC with $\gamma^{\frac{1}{3}} \; {}^{(3)}R$ and then $K$']
flab += [r'Fix IC with ${}^{(3)}R$ and then $K$']
loc = 'UD'

plt.figure(figsize=(25, 7))
plt.subplot(151)
for f in allfs:
    plt.plot(Lin.evo.a(f['t'])/Lin.evo.a(1), f['drho_'+loc])
plt.grid()
plt.title(r'$\delta_{UD}$')
plt.xlabel(r'$a/a_{IN}$')
#plt.ylim(-1, 30)
plt.xlim(30, 60)

plt.subplot(152)
for f in allfs:
    plt.semilogy(Lin.evo.a(f['t'])/Lin.evo.a(1), abs(f['K_'+loc]))
    plt.scatter(Lin.evo.a(f['t'])/Lin.evo.a(1), abs(f['K_'+loc]))
plt.grid()
plt.title(r'$|K_{UD}|$')
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(30, 60)
plt.ylim(5e-3, 2e-2)

plt.subplot(153)
for f in allfs:
    plt.semilogy(Lin.evo.a(f['t'])/Lin.evo.a(1), f['gdet_'+loc])
plt.grid()
plt.title(r'$\gamma_{UD}$')
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(30, 60)
plt.ylim(1e-6, 1e-3)

plt.subplot(154)
for f in allfs:
    plt.semilogy(Lin.evo.a(f['t'])/Lin.evo.a(1), abs((Lin.evo.a(f['t'])**2)*f['RicciS_'+loc]*(L**2)))
plt.grid()
plt.title(r'$|a^{2} \; {}^{(3)}R_{UD}| \;\; [\lambda_{pert}^{-2}]$')
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(30, 60)
#plt.ylim(1, 2000)

plt.subplot(155)
for f, lab in zip(allfs, flab):
    plt.semilogy(Lin.evo.a(f['t'])/Lin.evo.a(1), abs((f['gdet_OD']**(1/3))*f['RicciS_'+loc]*(L**2)), label=lab)
plt.grid()
plt.title(r'$|\gamma_{UD}^{\frac{1}{3}} \; {}^{(3)}R_{UD}| \;\; [\lambda_{pert}^{-2}]$')
plt.xlabel(r'$a/a_{IN}$')
plt.xlim(30, 60)
#plt.ylim(3e-1, 6e2)
plt.legend(bbox_to_anchor=(1,1))

plt.subplots_adjust(wspace=0.25)

# %%
fc = pd.read_table(paramH['datapath']+'constraints.csv', delimiter=',')
an = Lin.evo.a(fH['t'])/Lin.evo.a(1)
plt.figure(figsize=(7, 10))
labsize = 25
alphafac = 0.1
locs = ['maxabs', 'highQabs', 'medianabs', 'lowQabs', 'minabs']
loclabs = ['max', 'first quartile', 'median', 'third quartile', 'min']
cols = plt.cm.viridis(np.linspace(0,1,len(locs)))

ax = plt.subplot(211)
for i, loc, in enumerate(locs):
    for n in range(3):
        varstr = 'Mom'+str(n+1)+'/MomEScale_'+loc
        var = np.array(fc[varstr])
        if n==0:
            ax.semilogy(an, var, color=cols[i], linestyle='-', label=loclabs[i])
        else:
            ax.semilogy(an, var, color=cols[i], linestyle='-')
ax.grid()
ax.legend(bbox_to_anchor=(1,1))
ax.set_xticklabels([])
ax.set_ylim(5e-10, 1)
ax.set_ylabel(r'$|\mathcal{M}_{i}/[\mathcal{M}]|$', fontsize=labsize)


ax = plt.subplot(212)
for i, loc, in enumerate(locs):
        varstr = 'Ham/HamEScale_'+loc
        var = np.array(fc[varstr])
        ax.semilogy(an, var, color=cols[i], linestyle='-')
ax.grid()
ax.set_ylim(1e-11, 2)
ax.set_xlabel(r'$a/a_{IN}$', fontsize=labsize)
ax.set_ylabel(r'$|\mathcal{H}/[\mathcal{H}]|$', fontsize=labsize)

plt.subplots_adjust(hspace=0)
