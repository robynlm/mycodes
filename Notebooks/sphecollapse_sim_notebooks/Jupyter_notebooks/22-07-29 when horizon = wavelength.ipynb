# %%
import numpy as np
from data_analysis_codes import param
from data_analysis_codes.tools import LinData
import matplotlib.pyplot as plt
from data_analysis_codes.tools import ReadingTools as RRead

# %%
param = RRead.read_parameters('pflrw_d3e2_L1821_t1_N128_LCDM')
Lin = LinData.LinData_Class(param)
# Out:
#  read time file

# %%
t = np.arange(1263.5, 1264.5, 0.1)

# %%
H = Lin.evo.Hprop(t)
an = Lin.an_initial(t)
z = Lin.evo.z(t)

# %%
z
# Out:
# array([1.56163047, 1.56148976, 1.56134907, 1.5612084 , 1.56106775,
#        1.56092711, 1.5607865 , 1.5606459 , 1.56050532, 1.56036476])

# %%
plt.plot(t , 1/H)
plt.axhline(y = sim.lambda_pert)
plt.grid()

# %%
plt.semilogx(z , 1/H)
plt.axhline(y = sim.lambda_pert)
plt.grid()
