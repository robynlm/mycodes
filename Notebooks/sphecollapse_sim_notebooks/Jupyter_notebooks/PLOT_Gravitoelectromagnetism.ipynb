# %%
from data_analysis_codes import param
import matplotlib.pyplot as plt
from data_analysis_codes.tools import Cstyle
from data_analysis_codes.tools import LinData
import numpy as np
import h5py
from data_analysis_codes.tools import ReadingTools as RRead
from data_analysis_codes.tools import Plot2d
from matplotlib import ticker
plt.style.use(Cstyle.style1)

# %%
p = param.pflrw_d3e2_L1821_t1_N64_LCDM()
Lin = LinData.LinData_Class(p, '/home/robynm/simulations/'+p.sim_name+'/')
PLT = Plot2d.MyPlot2dclass(p, Lin)
# Out:
#  read time file

# %%
it = 0
it_file_name = '/home/robynm/simulations/'+p.sim_name+'/output-0000/'+p.parfile_name+'/'+'all_iterations/'+p.sim_name
f = h5py.File('{}_it_{:06d}.hdf5'.format(it_file_name, it), 'r')
delta = np.array(f['delta'])
R3 = np.array(f['RicciS'])
E2 = np.array(f['E2'])
B2 = np.array(f['B2'])

# %%
plt.figure(figsize=(20,7))
plt.subplot(131)
data = R3
dataxd = np.array([data[:, j, j] for j in range(64)])
plt.pcolormesh(Lin.d3xyz/p.L, Lin.d3xyz/p.L, dataxd, shading='gouraud', cmap=plt.cm.get_cmap('Blues'))
plt.gca().set_aspect("equal")
plt.colorbar(format='%.1e', extend='both', ticks=ticker.MaxNLocator(nbins=9))
plt.xlabel('x/L')
plt.ylabel('d/L')

plt.subplot(132)
data = E2
dataxd = np.array([data[:, j, j] for j in range(64)])
plt.pcolormesh(Lin.d3xyz/p.L, Lin.d3xyz/p.L, dataxd, shading='gouraud', cmap=plt.cm.get_cmap('Reds'))
plt.gca().set_aspect("equal")
plt.colorbar(format='%.1e', extend='both', ticks=ticker.MaxNLocator(nbins=9))
plt.xlabel('x/L')
plt.ylabel('d/L')

plt.subplot(133)
data = B2
dataxd = np.array([data[:, j, j] for j in range(64)])
plt.pcolormesh(Lin.d3xyz/p.L, Lin.d3xyz/p.L, dataxd, shading='gouraud', cmap=plt.cm.get_cmap('Greens'))
plt.gca().set_aspect("equal")
plt.colorbar(format='%.1e', extend='both', ticks=ticker.MaxNLocator(nbins=9))
plt.xlabel('x/L')
plt.ylabel('d/L')
# Out:
# <ipython-input-20-4e328d7806d7>:14: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(Lin.d3xyz/p.L, Lin.d3xyz/p.L, dataxd, cmap=plt.cm.get_cmap('Reds'))
# <ipython-input-20-4e328d7806d7>:23: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(Lin.d3xyz/p.L, Lin.d3xyz/p.L, dataxd, cmap=plt.cm.get_cmap('Greens'))
# Text(0, 0.5, 'd/L')
