# %%
import numpy as np
import matplotlib.pyplot as plt
from data_analysis_codes import param
from data_analysis_codes.tools import LinData
from data_analysis_codes.tools import ODUDLoc
from data_analysis_codes.tools import MassCalc
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
p = param.pflrw_d3e2_L1821_t1_N256_LCDM()
Lin = LinData.LinData_Class(p, '/home/robynm/simulations/pflrw_d3e2_L1821_t1_N256_LCDM/')
locfinder = ODUDLoc.ODUDLocClass(p)
MC = MassCalc.MassCalcClass(p, Lin, locfinder.findlocations()[0])
# Out:
#  could not read time file

# %%
xyz0 = Lin.d3xyz[locfinder.findlocations()[0][0]][0]
R = np.sqrt((Lin.d3x-xyz0)**2+(Lin.d3y-xyz0)**2+(Lin.d3z-xyz0)**2)
phi = R
plt.figure()
plt.imshow(phi[:,:,int(Lin.N/4)])

Box1 = np.ones(np.shape(phi))
Box0 = np.zeros(np.shape(phi))
gdet = (Lin.a_initial**6)*Box1
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Rinteg = 300

# %%
M, w = MC.CalcMass(phi, gdet, Rinteg)

# %%
M_th = (Lin.a_initial**3)*np.pi*(Rinteg**4)
Lin.N, M, M_th
# Out:
# (256, 909.692430736027, 909.9404562085172)

# %%
#M_th: 909.9404562085172

#N16:  853.934897916953
#N32:  894.6400354840898
#N64:  905.9563327069361
#N128: 908.957884149157
#N256: 909.692430736027

# %%
M = np.array([853.934897916953, 894.6400354840898, 905.9563327069361, 908.957884149157, 909.692430736027])
N = [16, 32, 64, 128, 256]
plt.figure()
plt.semilogy(N, abs(M/M_th-1))
plt.scatter(N, abs(M/M_th-1))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
M*Lin.Massfac
# Out:
# array([1.78447068e+22, 1.86953235e+22, 1.89318005e+22, 1.89945241e+22,
#        1.90098739e+22])

# %%
plt.figure()
ir = np.linspace(Rinteg-2*p.dx/2, Rinteg+2*p.dx/2, 200) 
w = []
for i in ir:
    coord = xyz0+i
    w +=[MC.getWeights(coord, xyz0, xyz0, Rinteg)]
plt.plot(np.arange(200), w)
ir = np.linspace((Rinteg-2*p.dx/2)/np.sqrt(2), (Rinteg+2*p.dx/2)/np.sqrt(2), 200) 
w = []
for i in ir:
    coord = xyz0+i
    w +=[MC.getWeights(coord, coord, xyz0, Rinteg)]
plt.plot(np.arange(200), w)
ir = np.linspace((Rinteg-2*p.dx/2)/np.sqrt(3), (Rinteg+2*p.dx/2)/np.sqrt(3), 200) 
w = []
for i in ir:
    coord = xyz0+i
    w +=[MC.getWeights(coord, coord, coord, Rinteg)]
plt.plot(np.arange(200), w)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
P = MC.Collect_points(Rinteg)
X = []
Y = []
Z = []
for po in P:
    X += [po[0]]
    Y += [po[1]]
    Z += [po[2]]
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter3D(X, Y, Z, s=1)
# Out:
# <img src="data:image/png;base64,..." width="640">
