# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from data_analysis_codes.tools import PlottingTools as RPlot
from data_analysis_codes import param
from data_analysis_codes.tools import Cstyle
from data_analysis_codes.tools import LinData
plt.style.use(Cstyle.style1)

# %%
sim = param.pflrw_A0_L1821_t1_N128_LCDM()
f = pd.read_table('/home/robynm/simulations/'+sim.sim_name+'/h5_data.csv', delimiter=',')
Lin = LinData.LinData_Class(sim, '/home/robynm/simulations/'+sim.sim_name+'/')
# Out:
#  read time file

# %%
sim.expansion_evo, sim.expansion_ini
# Out:
# ('LCDM', 'LCDM')

# %%
t = np.array(f['t'])
gdet = np.array(f['gdet_av'])
a = np.array(f['a_av'])
R3 = np.array(f['RicciS_av'])
rho = np.array(f['rho_av'])
K = np.array(f['K_av'])
A2 = np.array(f['A2_av'])
Ham = np.array(f['Ham_av'])

# %%
plt.loglog(Lin.z(t), abs(Ham), label='Hamiltonian')
#plt.semilogy(t, abs(A2))
plt.loglog(Lin.z(t), abs(K/Lin.K(t)-1), label=r'$|K/\bar{K}-1|$')
plt.loglog(Lin.z(t), abs(rho/Lin.rho(t)-1), label=r'$|\rho/\bar{\rho}-1|$')
#plt.semilogy(t, abs(R3))
plt.loglog(Lin.z(t), abs(a/Lin.a(t)-1), label=r'$|a/\bar{a}-1|$')
plt.loglog(Lin.z(t), abs(gdet/Lin.gdet(t)-1), label=r'$|\gamma/\bar{\gamma}-1|$')
plt.grid()
plt.xlabel('z')
plt.xlim(400, 0.4)
plt.legend(bbox_to_anchor=(1,1))

# %%
plt.semilogx(Lin.z(t), Lin.Omega_m(t))
plt.grid()
plt.xlabel('z')
plt.xlim(400, 0.4)
# Out:
# (400, 0.4)
