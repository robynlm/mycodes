# %%
import numpy as np
import matplotlib.pyplot as plt
from data_analysis_codes.tools import Cstyle
plt.style.use(Cstyle.style1)
from data_analysis_codes.tools import ReadingTools as RRead

# %%
it, t16, Ham16 = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A0_L1821_t1_N16_LCDM/ml_bssn-ml_ham.average.asc')
it, t32, Ham32 = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A0_L1821_t1_N32_LCDM/ml_bssn-ml_ham.average.asc')
it, t64, Ham64 = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A0_L1821_t1_N64_LCDM/ml_bssn-ml_ham.average.asc')
it, t128, Ham128 = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A0_L1821_t1_N128_LCDM/ml_bssn-ml_ham.average.asc')
it, t16_TV, Ham16_TV = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A0_L1821_t1_N16_LCDM_TimeVar/ml_bssn-ml_ham.average.asc')
it, t32_TV, Ham32_TV = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A0_L1821_t1_N32_LCDM_TimeVar/ml_bssn-ml_ham.average.asc')
it, t64_TV, Ham64_TV = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A0_L1821_t1_N64_LCDM_TimeVar/ml_bssn-ml_ham.average.asc')
it, t128_TV, Ham128_TV = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A0_L1821_t1_N128_LCDM_TimeVar/ml_bssn-ml_ham.average.asc')

# %%
plt.semilogy(t16, abs(Ham16), 'C0', label='N=16, Nt='+str(len(t16)))
plt.semilogy(t16_TV, abs(Ham16_TV), 'C0-.', label='N=16, Nt='+str(len(t16_TV)))
plt.semilogy(t32, abs(Ham32), 'C1', label='N=32, Nt='+str(len(t32)))
plt.semilogy(t32_TV, abs(Ham32_TV), 'C1-.', label='N=32, Nt='+str(len(t32_TV)))
plt.semilogy(t64, abs(Ham64), 'C2', label='N=64, Nt='+str(len(t64)))
plt.semilogy(t64_TV, abs(Ham64_TV), 'C2-.', label='N=64, Nt='+str(len(t64_TV)))
plt.semilogy(t128, abs(Ham128), 'C3', label='N=128, Nt='+str(len(t128)))
plt.semilogy(t128_TV, abs(Ham128_TV), 'C3-.', label='N=128, Nt='+str(len(t128_TV)))
#plt.axvline(x=1600)
plt.title('Pure FLRW LCDM')
plt.grid()
plt.legend(bbox_to_anchor=(1,1))
plt.ylabel(r'$|Ham|$')
plt.xlabel('t')
#plt.ylim(1e-11, 1e-6)
#plt.xlim(0, 10)
# Out:
# Text(0.5, 0, 't')

# %%
it, t16, Ham16 = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A1e4_L1821_t1_N16_LCDM/ml_bssn-ml_ham.average.asc')
it, t32, Ham32 = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A1e4_L1821_t1_N32_LCDM/ml_bssn-ml_ham.average.asc')
it, t64, Ham64 = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A1e4_L1821_t1_N64_LCDM/ml_bssn-ml_ham.average.asc')
it, t128, Ham128 = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A1e4_L1821_t1_N128_LCDM/ml_bssn-ml_ham.average.asc')
it, t16_TV, Ham16_TV = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A1e4_L1821_t1_N16_LCDM_TimeVar/ml_bssn-ml_ham.average.asc')
it, t32_TV, Ham32_TV = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A1e4_L1821_t1_N32_LCDM_TimeVar/ml_bssn-ml_ham.average.asc')
it, t64_TV, Ham64_TV = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A1e4_L1821_t1_N64_LCDM_TimeVar/ml_bssn-ml_ham.average.asc')
it, t128_TV, Ham128_TV = RRead.readasctable_scalar('/home/robynm/simulations/pflrw_A1e4_L1821_t1_N128_LCDM_TimeVar/ml_bssn-ml_ham.average.asc')

# %%
plt.semilogy(t16, abs(Ham16), 'C0', label='N=16, Nt='+str(len(t16)))
plt.semilogy(t16_TV, abs(Ham16_TV), 'C0-.', label='N=16, Nt='+str(len(t16_TV)))
plt.semilogy(t32, abs(Ham32), 'C1', label='N=32, Nt='+str(len(t32)))
plt.semilogy(t32_TV, abs(Ham32_TV), 'C1-.', label='N=32, Nt='+str(len(t32_TV)))
plt.semilogy(t64, abs(Ham64), 'C2', label='N=64, Nt='+str(len(t64)))
plt.semilogy(t64_TV, abs(Ham64_TV), 'C2-.', label='N=64, Nt='+str(len(t64_TV)))
plt.semilogy(t128, abs(Ham128), 'C3', label='N=128, Nt='+str(len(t128)))
plt.semilogy(t128_TV, abs(Ham128_TV), 'C3-.', label='N=128, Nt='+str(len(t128_TV)))
#plt.axvline(x=1600)
plt.title('FLRW LCDM with Amp_pert = 1e-4')
plt.grid()
plt.legend(bbox_to_anchor=(1,1))
plt.ylabel(r'$|Ham|$')
plt.xlabel('t')
#plt.ylim(1e-14, 1e-9)
#plt.xlim(0, 10)
# Out:
# Text(0.5, 0, 't')
