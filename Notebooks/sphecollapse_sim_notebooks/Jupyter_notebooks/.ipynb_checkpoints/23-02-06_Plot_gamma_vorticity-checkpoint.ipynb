# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data_analysis_codes.tools import LinData
from data_analysis_codes.tools import ReadingTools as RRead
from data_analysis_codes.tools import Cstyle
plt.style.use(Cstyle.style1)

# %%
param = RRead.read_parameters('pflrw_d3e2_L1821_t1_N128_LCDM')
Lin = LinData.LinData_Class(param)
f = pd.read_table(param['HorSpath']+param['simname']+'/h5_data.csv', delimiter=',')
# Out:
#  read time file

# %%
an = Lin.an_initial(f['t'])
plt.semilogy(an, f['gdet_OD'], label='OD')
plt.semilogy(an, f['gdet_midOD'], label='midOD')
plt.semilogy(an, f['gdet_cent'], label='cent')
plt.semilogy(an, f['gdet_midUD'], label='midUD')
plt.semilogy(an, f['gdet_UD'], label='UD')
plt.semilogy(an, f['gdet_L1'], label='average')
plt.semilogy(an, f['gdet_av'], label='domain average')
plt.grid()
plt.legend(bbox_to_anchor=(1,1))
plt.xlabel(r'$a/a_{IN}$')
plt.ylabel(r'$\gamma$')
# Out:
# Text(0, 0.5, '$\\gamma$')
