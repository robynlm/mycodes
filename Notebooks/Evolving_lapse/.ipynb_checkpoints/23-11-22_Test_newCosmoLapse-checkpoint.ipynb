# %%
import sys
sys.path.append("/users/munozr/mycodes")
import numpy as np
import matplotlib.pyplot as plt
from data_analysis_codes.tools import Cstyle
plt.style.use(Cstyle.style1)
from data_analysis_codes.tools import ReadingTools as RRead
from data_analysis_codes.tools import LinData
import pandas as pd
from data_analysis_codes.tools import NumMethods

# %%
paramA = RRead.read_parameters('pflrw_d3e2_L1206_t1_N128_EdS')
fA = pd.read_table(paramA['datapath']+'h5_data.csv', delimiter=',')
fAc = pd.read_table(paramA['datapath']+'constraints.csv', delimiter=',')

# %%
param_sync = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_nCL_sync')
f_sync = pd.read_table(param_sync['datapath']+'h5_data.csv', delimiter=',')
fc_sync = pd.read_table(param_sync['datapath']+'constraints.csv', delimiter=',')

# %%
for loc in ['OD', 'midOD', 'cent', 'midUD', 'UD', 'av', 'L1', 'min', 'max']:
    plt.plot(f_sync['t'], f_sync['tau_'+loc])

# %%
param_PCTDnCL = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_nCL_Puncture')
f_PCTDnCL = pd.read_table(param_PCTDnCL['datapath']+'h5_data.csv', delimiter=',')
fc_PCTDnCL = pd.read_table(param_PCTDnCL['datapath']+'constraints.csv', delimiter=',')

param_PCTDnnCL = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_nnCL_Puncture')
f_PCTDnnCL = pd.read_table(param_PCTDnnCL['datapath']+'h5_data.csv', delimiter=',')
fc_PCTDnnCL = pd.read_table(param_PCTDnnCL['datapath']+'constraints.csv', delimiter=',')

param_CPCTDnnCL = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_nnCL_CosmoPuncture')
f_CPCTDnnCL = pd.read_table(param_CPCTDnnCL['datapath']+'h5_data.csv', delimiter=',')
fc_CPCTDnnCL = pd.read_table(param_CPCTDnnCL['datapath']+'constraints.csv', delimiter=',')

param_PCTD = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_CLPT_Puncture')
f_PCTD = pd.read_table(param_PCTD['datapath']+'h5_data.csv', delimiter=',')
fc_PCTD = pd.read_table(param_PCTD['datapath']+'constraints.csv', delimiter=',')

param_PGRH = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_GRH_Puncture')
f_PGRH = pd.read_table(param_PGRH['datapath']+'h5_data.csv', delimiter=',')
fc_PGRH = pd.read_table(param_PGRH['datapath']+'constraints.csv', delimiter=',')

# %%
param_CTDP = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_CLPT_mKPunc')
f_CTDP = pd.read_table(param_CTDP['datapath']+'h5_data.csv', delimiter=',')
fc_CTDP = pd.read_table(param_CTDP['datapath']+'constraints.csv', delimiter=',')

# %%
plt.subplot(121)
plt.semilogy(f_PGRH['tau_OD'], f_PGRH['rho_u_OD'])
plt.semilogy(f_PCTD['tau_OD'], f_PCTD['rho_u_OD'])
plt.semilogy(f_PCTDnCL['tau_OD'], f_PCTDnCL['rho_u_OD'])
plt.semilogy(f_PCTDnnCL['tau_OD'], f_PCTDnnCL['rho_u_OD'])
plt.semilogy(f_CPCTDnnCL['tau_OD'], f_CPCTDnnCL['rho_u_OD'])
plt.subplot(122)
plt.semilogy(f_PGRH['tau_OD'], abs(f_PGRH['Theta_OD']))
plt.semilogy(f_PCTD['tau_OD'], abs(f_PCTD['Theta_OD']))
plt.semilogy(f_PCTDnCL['tau_OD'], abs(f_PCTDnCL['Theta_OD']))
plt.semilogy(f_PCTDnnCL['tau_OD'], abs(f_PCTDnnCL['Theta_OD']))
plt.semilogy(f_CPCTDnnCL['tau_OD'], abs(f_CPCTDnnCL['Theta_OD']))

# %%
plt.subplot(121)
plt.semilogy(f_CTDP['tau_OD'], f_CTDP['rho_u_OD'])
plt.semilogy(f_CPCTDnnCL['tau_OD'], f_CPCTDnnCL['rho_u_OD'])
plt.subplot(122)
plt.semilogy(f_CTDP['tau_OD'], abs(f_CTDP['Theta_OD']))
plt.semilogy(f_CPCTDnnCL['tau_OD'], abs(f_CPCTDnnCL['Theta_OD']))

# %%
for loc in ['midOD', 'cent', 'midUD']:
    plt.semilogy(f_PCTDnnCL['tau_'+loc], abs(f_PCTDnnCL['betax_'+loc]), label=loc+r' with $\alpha^2$')
    plt.semilogy(f_CTDP['tau_'+loc], abs(f_CTDP['betax_'+loc]), linestyle='--', label=loc+r' with $\alpha^0$')
plt.grid()
plt.legend(bbox_to_anchor=(1,1))
plt.ylabel(r'$\beta_x$')
plt.xlabel(r'$\tau$')
# Out:
# Text(0.5, 0, '$\\tau$')

# %%
for loc in ['OD', 'midOD', 'cent', 'midUD', 'UD', 'av', 'L1', 'min', 'max']:
    plt.semilogy(f_PCTD['tau_'+loc], abs(f_PCTD['betax_'+loc]/f_PCTDnnCL['betax_'+loc] - 1))

# %%
param_CTDnCLmK = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_nCL_mK')
f_CTDnCLmK = pd.read_table(param_CTDnCLmK['datapath']+'h5_data.csv', delimiter=',')
fc_CTDnCLmK = pd.read_table(param_CTDnCLmK['datapath']+'constraints.csv', delimiter=',')

param_GRHmK = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_GRH_CLPT_mK')
f32_GRHmK = pd.read_table(param_GRHmK['datapath']+'h5_data.csv', delimiter=',')
fc32_GRHmK = pd.read_table(param_GRHmK['datapath']+'constraints.csv', delimiter=',')

param_CTDmK = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_CLPT_mK')
f_CTDmK = pd.read_table(param_CTDmK['datapath']+'h5_data.csv', delimiter=',')
fc_CTDmK = pd.read_table(param_CTDmK['datapath']+'constraints.csv', delimiter=',')

# %%
for loc in ['OD']:
    plt.semilogy(f_CTDmK['tau_'+loc], abs(f_CTDmK['dtalpha_'+loc]))
    plt.semilogy(f_CTDnCLmK['tau_'+loc], abs(f_CTDnCLmK['dtalpha_'+loc]))
    plt.scatter(f_CTDmK['tau_'+loc], abs(f_CTDmK['dtalpha_'+loc]))
    plt.scatter(f_CTDnCLmK['tau_'+loc], abs(f_CTDnCLmK['dtalpha_'+loc]))
plt.xlim(625, 700)
# Out:
# (625.0, 700.0)

# %%
for loc in ['OD']:
    plt.semilogy(f_CTDmK['tau_'+loc], abs(f_CTDmK['K_'+loc] + 2/f_CTDmK['tau_'+loc]))
    plt.semilogy(f_CTDnCLmK['tau_'+loc], abs(f_CTDnCLmK['K_'+loc] + 2/f_CTDnCLmK['tau_'+loc]))
plt.xlim(625, 750)
#plt.ylim(1e-3, 1e-2)
# Out:
# (625.0, 750.0)

# %%
for loc in ['OD']:
    plt.semilogy(f_CTDmK['tau_'+loc], abs(f_CTDmK['Theta_'+loc]))
    plt.semilogy(f_CTDnCLmK['tau_'+loc], abs(f_CTDnCLmK['Theta_'+loc]))
#plt.xlim(625, 750)

# %%
for loc in ['OD', 'midOD', 'cent', 'midUD', 'UD', 'av', 'L1']:
    plt.semilogy(abs(f_CTDmK['alpha_'+loc][:len(f_CTDnCLmK['alpha_'+loc])]/f_CTDnCLmK['alpha_'+loc] - 1))
#    plt.semilogy(abs(f_CTDmK['tau_'+loc][:len(f_CTDnCLmK['alpha_'+loc])]/f_CTDnCLmK['tau_'+loc] - 1))
    
plt.ylim(1e-20, 1e1)
# Out:
# (1e-20, 10.0)

# %%
RRead.plot_constraints(fc_CPCTDnnCL)
RRead.plot_constraintsEScale(fc_CPCTDnnCL)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
