# %%
import sys
sys.path.append("/users/munozr/mycodes")
import h5py
import numpy as np
import matplotlib.pyplot as plt
from data_analysis_codes.tools import Cstyle
plt.style.use(Cstyle.style1)
from data_analysis_codes.tools import ReadingTools as RRead
from data_analysis_codes.tools import LinData
import pandas as pd
from data_analysis_codes.tools import NumMethods

# %%
paramA = RRead.read_parameters('pflrw_d3e2_L1206_t1_N128_EdS')
fA = pd.read_table(paramA['datapath']+'h5_data.csv', delimiter=',')
fAc = pd.read_table(paramA['datapath']+'constraints.csv', delimiter=',')

# %%
param_t = RRead.read_parameters('pflrw_d3e2_L1206_t1_N32_EdS_CLPT_mKav')
f_t = pd.read_table(param_t['datapath']+'h5_data.csv', delimiter=',')
fc_t = pd.read_table(param_t['datapath']+'constraints.csv', delimiter=',')

# %%
plt.semilogy(f_t['t'], abs(f_t['K_L1']/f_t['Ktraceaverage_OD'] - 1)) #=midOD
plt.semilogy(f_t['t'], abs(f_t['K_L1']/f_t['Ktraceaverage_F'] - 1))
plt.semilogy(f_t['t'], abs(f_t['K_L1']/f_t['Ktraceaverage_cent'] - 1)) #=midUD=UD

# %%
plt.semilogy(f_t['t'], abs(f_t['Ktraceaverage_OD'])) #=midOD
plt.semilogy(f_t['t'], abs(f_t['Ktraceaverage_F']))
plt.semilogy(f_t['t'], abs(f_t['Ktraceaverage_cent'])) #=midUD=UD

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
plt.plot(f_t['t'], f_t['alp_UD'])
plt.plot(f_t['t'], f_t['alp_OD'])
plt.grid()
plt.title(r'$\alpha$')
plt.xlabel('t')
plt.ylim(0.8, 1.05)
plt.subplot(122)
plt.plot(f_t['t'], f_t['dtalp_UD'], label='UD')
plt.plot(f_t['t'], f_t['dtalp_OD'], label='OD')
plt.grid()
plt.title(r'$\partial_t \alpha$')
plt.xlabel('t')
plt.ylim(-0.025, 0.025)
# Out:
# (-0.025, 0.025)

# %%
plt.semilogy(f_t['tau_OD'], f_t[' _OD'])
